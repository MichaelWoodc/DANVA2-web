# %%
import urllib.request

url = "https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml"
save_path = r"C:\Users\micha\Documents\haarcascade_frontalface_default.xml"  # choose any folder
urllib.request.urlretrieve(url, save_path)

print(f"Downloaded Haar cascade to: {save_path}")
# Out:
# Downloaded Haar cascade to: C:\Users\micha\Documents\haarcascade_frontalface_default.xml

# %%
import cv2

face_cascade = cv2.CascadeClassifier(r"C:\Users\micha\Documents\haarcascade_frontalface_default.xml")
print(face_cascade.empty())  # Should print False

# Process files 1.jpg → 24.jpg
for i in range(1, 25):
    filename = f"{i}.jpg"
    img_path = os.path.join(input_folder, filename)
    if not os.path.exists(img_path):
        print(f"{filename} not found, skipping")
        continue

    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Detect faces
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    # Blur each detected face
    for (x, y, w, h) in faces:
        face = img[y:y+h, x:x+w]
        face_blurred = cv2.GaussianBlur(face, (51, 51), 30)
        img[y:y+h, x:x+w] = face_blurred

    # Save blurred image
    output_path = os.path.join(input_folder, f"{i}_blurred.jpg")
    cv2.imwrite(output_path, img)
    print(f"Saved: {output_path}")

print("All images processed")
# Out:
# False
# Saved: stimFiles\adultFaces\1_blurred.jpg
# Saved: stimFiles\adultFaces\2_blurred.jpg
# Saved: stimFiles\adultFaces\3_blurred.jpg
# Saved: stimFiles\adultFaces\4_blurred.jpg
# Saved: stimFiles\adultFaces\5_blurred.jpg
# Saved: stimFiles\adultFaces\6_blurred.jpg
# Saved: stimFiles\adultFaces\7_blurred.jpg
# Saved: stimFiles\adultFaces\8_blurred.jpg
# Saved: stimFiles\adultFaces\9_blurred.jpg
# Saved: stimFiles\adultFaces\10_blurred.jpg
# Saved: stimFiles\adultFaces\11_blurred.jpg
# Saved: stimFiles\adultFaces\12_blurred.jpg
# Saved: stimFiles\adultFaces\13_blurred.jpg
# Saved: stimFiles\adultFaces\14_blurred.jpg
# Saved: stimFiles\adultFaces\15_blurred.jpg
# Saved: stimFiles\adultFaces\16_blurred.jpg
# Saved: stimFiles\adultFaces\17_blurred.jpg
# Saved: stimFiles\adultFaces\18_blurred.jpg
# Saved: stimFiles\adultFaces\19_blurred.jpg
# Saved: stimFiles\adultFaces\20_blurred.jpg
# Saved: stimFiles\adultFaces\21_blurred.jpg
# Saved: stimFiles\adultFaces\22_blurred.jpg
# ...

# %%
import cv2
import os

# Paths
input_folder = r"images"

# Load Haar cascade
face_cascade_path = r"C:\Users\micha\Documents\haarcascade_frontalface_default.xml"
face_cascade = cv2.CascadeClassifier(face_cascade_path)

if face_cascade.empty():
    raise Exception("Failed to load Haar cascade XML!")

# Process files 1.jpg > 24.jpg
for i in range(1, 25):
    filename = f"{i}.jpg"
    img_path = os.path.join(input_folder, filename)
    if not os.path.exists(img_path):
        print(f"{filename} not found, skipping")
        continue

    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Detect faces
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    # Blur each detected face
    for (x, y, w, h) in faces:
        face = img[y:y+h, x:x+w]
        face_blurred = cv2.GaussianBlur(face, (51, 51), 30)
        img[y:y+h, x:x+w] = face_blurred

    # Overwrite the original image
    cv2.imwrite(img_path, img)
    print(f"Overwritten: {img_path}")

print("All images processed")
# Out:
# Overwritten: images\1.jpg
# Overwritten: images\2.jpg
# Overwritten: images\3.jpg
# Overwritten: images\4.jpg
# Overwritten: images\5.jpg
# Overwritten: images\6.jpg
# Overwritten: images\7.jpg
# Overwritten: images\8.jpg
# Overwritten: images\9.jpg
# Overwritten: images\10.jpg
# Overwritten: images\11.jpg
# Overwritten: images\12.jpg
# Overwritten: images\13.jpg
# Overwritten: images\14.jpg
# Overwritten: images\15.jpg
# Overwritten: images\16.jpg
# Overwritten: images\17.jpg
# Overwritten: images\18.jpg
# Overwritten: images\19.jpg
# Overwritten: images\20.jpg
# Overwritten: images\21.jpg
# Overwritten: images\22.jpg
# Overwritten: images\23.jpg
# Overwritten: images\24.jpg
# All images processed ✅

# %%
import cv2
import os

# Load Haar cascade
face_cascade_path = r"C:\Users\micha\Documents\haarcascade_frontalface_default.xml"
face_cascade = cv2.CascadeClassifier(face_cascade_path)

if face_cascade.empty():
    raise Exception("Failed to load Haar cascade XML!")

# Start from current working directory
root_dir = os.getcwd()

# Recursively process all .jpg files
for dirpath, dirnames, filenames in os.walk(root_dir):
    for filename in filenames:
        if filename.lower().endswith(".jpg"):
            img_path = os.path.join(dirpath, filename)
            img = cv2.imread(img_path)
            if img is None:
                print(f"Failed to read {img_path}, skipping")
                continue

            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

            # Blur each detected face
            for (x, y, w, h) in faces:
                face = img[y:y+h, x:x+w]
                face_blurred = cv2.GaussianBlur(face, (51, 51), 30)
                img[y:y+h, x:x+w] = face_blurred

            # Overwrite the original image
            cv2.imwrite(img_path, img)
            print(f"Processed and overwritten: {img_path}")

print("All images in all subfolders processed")
# Out:
# Processed and overwritten: c:\Users\micha\DANVA2-web\images\1.jpg
# Processed and overwritten: c:\Users\micha\DANVA2-web\images\10.jpg
# Processed and overwritten: c:\Users\micha\DANVA2-web\images\11.jpg
# Processed and overwritten: c:\Users\micha\DANVA2-web\images\12.jpg
# Processed and overwritten: c:\Users\micha\DANVA2-web\images\13.jpg
# Processed and overwritten: c:\Users\micha\DANVA2-web\images\14.jpg
# Processed and overwritten: c:\Users\micha\DANVA2-web\images\15.jpg
# Processed and overwritten: c:\Users\micha\DANVA2-web\images\16.jpg
# Processed and overwritten: c:\Users\micha\DANVA2-web\images\17.jpg
# Processed and overwritten: c:\Users\micha\DANVA2-web\images\18.jpg
# Processed and overwritten: c:\Users\micha\DANVA2-web\images\19.jpg
# Processed and overwritten: c:\Users\micha\DANVA2-web\images\2.jpg
# Processed and overwritten: c:\Users\micha\DANVA2-web\images\20.jpg
# Processed and overwritten: c:\Users\micha\DANVA2-web\images\21.jpg
# ...
